# %% [markdown]
# # Front Page

# %% [markdown]
# ![front-page.JPG](attachment:front-page.JPG)

# %% [markdown]
# # Search Page

# %% [markdown]
# ![search-page.JPG](attachment:search-page.JPG)

# %% [markdown]
# # Result Page

# %% [markdown]
# ![vedio-details-page.jpg](attachment:vedio-details-page.jpg)

# %% [markdown]
# # Comment Page

# %% [markdown]
# ![review-page.JPG](attachment:review-page.JPG)

# %% [markdown]
# # Mysql-Table-youtuber-channel

# %% [markdown]
# ![MYSQL_data2.JPG](attachment:MYSQL_data2.JPG)

# %% [markdown]
# # Mysql-Table-youtuber

# %% [markdown]
# ![MYSQL_data1.JPG](attachment:MYSQL_data1.JPG)

# %% [markdown]
# # Thumbnil and vedio storage

# %% [markdown]
# ![images.JPG](attachment:images.JPG)

# %% [markdown]
# # Thumbnils-local-storage

# %% [markdown]
# ![thumbnils.JPG](attachment:thumbnils.JPG)

# %% [markdown]
# # Vedios-local-storage

# %% [markdown]
# ![vedios.JPG](attachment:vedios.JPG)

# %% [markdown]
# # Thumbnils-MongoDB-storage

# %% [markdown]
# ![mongodb-storage.JPG](attachment:mongodb-storage.JPG)

# %% [markdown]
# ![images_mongodb1.JPG](attachment:images_mongodb1.JPG)

# %% [markdown]
# ![images_mongodb2.JPG](attachment:images_mongodb2.JPG)

# %% [markdown]
# # Comments-Storage

# %% [markdown]
# ![comments1.JPG](attachment:comments1.JPG)

# %% [markdown]
# ![comments2.JPG](attachment:comments2.JPG)
